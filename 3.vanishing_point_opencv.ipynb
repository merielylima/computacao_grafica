# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 

plt.rcParams["figure.figsize"] = (15, 11)
img= np.ones([600,600,3])

# copia para a variavel sala
saida = img.copy()

#--------------------->> Pontos <<-------------------#
cv2.line(saida, (200,0), (600,600), (255,0,0), 1)#vermelha[0,600]
cv2.line(saida, (0,600), (400,0), (255,0,0), 1) #vermelha[600,0]
cv2.line(saida, (0,570), (300,150), (255,0,0), 1) # parede esquerda 
cv2.line(saida, (250,600), (300,150), (255,0,0), 1) # criado mudo 
cv2.line(saida, (260,600), (300,150), (255,0,0), 1) # criado mudo 

cv2.line(saida, (0,1), (300,150), (255,0,0), 1) #janelas esquerda
cv2.line(saida, (0,200), (300,150), (255,0,0), 1)#janelas esquerda

cv2.line(saida, (300,150), (600,300), (255,0,0), 1) #janelas direita
cv2.line(saida, (300,150), (600,1), (255,0,0), 1)#janelas direita

cv2.line(saida, (300,150), (600,380), (255,0,0), 1) #sofá red
cv2.line(saida, (300,150), (600,420), (255,0,0), 1) #sofá red
cv2.line(saida, (300,150), (390,600), (255,0,0), 1) #sofa 


#------------------------------>> Parede fundo <<------------------------------#
#cv2.rectangle(saida, (200,0), (400,300),(0,0,0),1)
cv2.line(saida, (200,0), (200,200),(0,0,0),1) # linha esquerda
cv2.rectangle(saida, (400,0), (400,300),(0,0,0),1) #linha direita
cv2.rectangle(saida, (285,300), (400,300),(0,0,0),1) #linha baixo
cv2.line(saida, (130,400), (119,418), (0,0,0), 1) #chão esquerda
cv2.line(saida, (98,453), (110,435), (0,0,0), 1) #chão esquerda 2
cv2.line(saida, (15,575), (0,600), (0,0,0), 1) #chão esquerda 3
cv2.line(saida, (400,300), (450,375), (0,0,0), 1) #chao direita 

#--------------------->> criado mudo <<-------------------#
#BASE DE CIMA
cv2.line(saida, (50,500), (15,550), (0,0,0), 1) #linha vertical esquerda
cv2.line(saida, (260,500), (250,550), (0,0,0), 1) #linha vertical direita
cv2.line(saida, (50,500), (260,500), (0,0,0), 1) #linha horizontal cima
cv2.line(saida, (15,550), (250,550), (0,0,0), 1) #linha horizontal baixo

#CORPO
cv2.line(saida, (15,600), (15,550), (0,0,0), 1) #linha vertical tras esquerda
cv2.line(saida, (261,560), (261,500), (0,0,0), 1) #linha vertical direita tras
cv2.line(saida, (250,600), (250,550), (0,0,0), 1) #linha vertical direita frente
cv2.line(saida, (255,600), (261,561), (0,0,0), 1) #linha vertical direita baixo

#--------------------->> Sofá <<-------------------#
#vertical
cv2.line(saida, (266,400), (285,300), (0,0,0), 1) #linha vertical direita base
cv2.line(saida, (285,250), (285,300), (0,0,0), 1) #linha vertical esquerda base 2
cv2.line(saida, (265,330), (285,250), (0,0,0), 1) #linha vertical direita assento
cv2.line(saida, (170,330), (230,250), (0,0,0), 1) #linha vertical esquerda assento
cv2.line(saida, (170,330), (170,245), (0,0,0), 1) #linha vertical esquerda ENCOSTO
cv2.line(saida, (230,200), (230,250), (0,0,0), 1) #linha vertical direita ENCOSTO
cv2.line(saida, (170,245), (230,200), (0,0,0), 1) #linha vertical esquerda 1 ENCOSTO
cv2.line(saida, (170,245), (230,200), (0,0,0), 1) #linha vertical esquerda 2 ENCOSTO
cv2.line(saida, (130,245), (130,400), (0,0,0), 1) #linha vertical esquerda 3 ENCOSTO
cv2.line(saida, (130,245), (200,200), (0,0,0), 1) #linha vertical esquerda 4 ENCOSTO
cv2.line(saida, (265,330), (265,400), (0,0,0), 1) #linha vertical direita base

#horizontal
cv2.line(saida, (130,400), (265,400), (0,0,0), 1) #linha horizontal down BASE
cv2.line(saida, (130,400), (265,400), (0,0,0), 1) #linha horizontal up BASE
cv2.line(saida, (230,250), (285,250), (0,0,0), 1) #linha horizontal up assento
cv2.line(saida, (170,330), (265,330), (0,0,0), 1) #linha horizontal down assento
cv2.line(saida, (230,200), (200,200), (0,0,0), 1) #linha horizontal up encosto
cv2.line(saida, (170,245), (130,245), (0,0,0), 1) #linha horizontal down encosto

#--------------------->> Abajur <<-------------------#
#topo
cv2.ellipse(saida,(83,380),(12,3),0,0,360,0,1)
#base
cv2.ellipse(saida,(80,520),(12,6),0,0,360,0,1)
#corpo
cv2.ellipse(saida,(80,475),(45,20),90,0,360,(255,255,2550),-1)
cv2.ellipse(saida,(80,475),(45,20),90,0,360,0,1)
#triangulo
cv2.line(saida, (35, 435), (130, 435), (0,0,0), 1) #horizontal
cv2.line(saida, (60, 430), (100, 430), (255,255,255), 7)# linha branca 
cv2.line(saida, (95, 380), (130, 435), (0,0,0), 1) #vertical direita
cv2.line(saida, (35, 435), (71, 380), (0,0,0), 1) #vertical esquerda

#--------------------->> Sofá 2 <<-------------------#
#horizontal
cv2.line(saida, (450,320), (520,320), (0,0,0), 1) #entorno
cv2.line(saida, (467,340), (510,340), (0,0,0), 1) #entorno
cv2.line(saida, (362,460), (510,460), (0,0,0), 1) #entorno
cv2.line(saida, (350,400), (450,400), (0,0,0), 1) #entorno
cv2.line(saida, (355,425), (466,425), (0,0,0), 1) #entorno
cv2.line(saida, (540,420), (600,420), (0,0,0), 1) #encosto
cv2.line(saida, (380,550), (540,550), (0,0,0), 1) #braço
cv2.line(saida, (385,570), (553,570), (0,0,0), 1) #braço

#vertical
cv2.line(saida, (450,400), (450,320), (0,0,0), 1) #entorno
cv2.line(saida, (600,380), (520,320), (0,0,0), 1) #entorno  
cv2.line(saida, (600,420), (510,340), (0,0,0), 1) #entorno  
cv2.line(saida, (540,420), (540,550), (0,0,0), 1) #encosto
cv2.line(saida, (510,340), (510,460), (0,0,0), 1) #entorno  
cv2.line(saida, (362,460), (385,570), (0,0,0), 1) #assento frente
cv2.line(saida, (510,460), (540,505), (0,0,0), 1) #assento tras
cv2.line(saida, (466,340), (466,425), (0,0,0), 1) #braço
cv2.line(saida, (450,400), (466,425), (0,0,0), 1) #braço 
cv2.line(saida, (540,550), (553,570), (0,0,0), 1) #braço 
cv2.line(saida, (380,550), (385,570), (0,0,0), 1) #braço 
cv2.line(saida, (380,550), (385,570), (0,0,0), 1) #braço 
cv2.line(saida, (350,400), (355,425), (0,0,0), 1) #braço  
cv2.line(saida, (450,320), (466,339), (0,0,0), 1) #braço 
cv2.line(saida, (553,570), (553,437), (0,0,0), 1) #braço
cv2.line(saida, (540,420), (553,437), (0,0,0), 1) #braço
cv2.line(saida, (600,437), (553,437), (0,0,0), 1) #braço
cv2.line(saida, (385,570), (385,600), (0,0,0), 1) #base
cv2.line(saida, (380,550), (380,600), (0,0,0), 1) #base braço
cv2.line(saida, (362,460), (362,585), (0,0,0), 1) #base 
cv2.line(saida, (355,420), (355,535), (0,0,0), 1) #base braço
cv2.line(saida, (365,600), (350,487), (0,0,0), 1) #base
cv2.line(saida, (350,400), (350,487), (0,0,0), 1) #base braço

#--------------------->> entorno janela esquerda <<-------------------#
#vertical
cv2.line(saida, (15, 10), (15, 195), (0,0,0), 1)
cv2.line(saida, (100, 50), (100, 183), (0,0,0), 1)
#horizontal
cv2.line(saida, (15, 10), (100, 50), (0,0,0), 1)
cv2.line(saida, (15,195),(100,183),(0,0,0),1)
#--------------------->> janela esquerda <<-------------------#
#vertical
cv2.line(saida, (25, 25), (25, 180), (0,0,0), 1)
cv2.line(saida, (92, 55), (92, 173), (0,0,0), 1)
#horizontal
cv2.line(saida, (25, 25), (92, 55), (0,0,0), 1)
cv2.line(saida, (25,180),(92,173),(0,0,0),1)

#--------------------->> Entorno janela direita <<-------------------#
#vertical
cv2.line(saida, (500, 50), (500, 250), (0,0,0), 1)
#horizontal
cv2.line(saida, (500, 50), (600, 1), (0,0,0), 1)
cv2.line(saida, (500,250),(599,300),(0,0,0),1)
#--------------------->> janela direita <<-------------------#
#vertical
cv2.line(saida, (510, 54), (510, 246), (0,0,0), 1)

#horizontal
cv2.line(saida, (510, 54), (600,15), (0,0,0), 1)
cv2.line(saida, (510,246),(600,285),(0,0,0),1)

'''
# VISUALIZAÇÃO plt
plt.axis("off") 
plt.imshow(saida)
plt.show()
'''
# VISUALIZAÇÃO opencv
cv2.imshow("SALA", saida)

cv2.waitKey(0)
cv2.destroyAllWindows()
