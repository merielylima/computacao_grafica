# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (15, 11)
img = np.ones([600,800,3]) 
plt.scatter(1, 200,c= 'k') #ponto inicial 

#---------- pontos de fuga ------------
plt.plot([1,800],[200,0], c= 'r') #1
plt.plot([1,800],[200,100], c= 'r') #2
plt.plot([1,800],[200,150], c= 'r') #3
plt.plot([1,800],[200,250], c= 'r') #4
plt.plot([1,800],[200,400], c= 'r') #5
plt.plot([1,800],[200,600], c= 'r') #6 

#---------- estrutura ------------
#horizontal 
plt.plot([300,800],[125,0], c= 'k') #1 telhado
plt.plot([250,800],[170,100], c= 'k') #2 telhado
plt.plot([300,800],[180,150], c= 'k') #3 telhado
plt.plot([320,380],[220,225], c= 'k') #4 porta
plt.plot([600,450],[237,228], c= 'k') #4 entornojanela cima --
plt.plot([590,455],[245,235], c= 'k') #4 janela cima
plt.plot([600,450],[350,312], c= 'k') #4 entorno janela baixo --
plt.plot([590,455],[337,307], c= 'k') #4 janela baixo
plt.plot([700,800],[245,250], c= 'k') #5 entorno janela 2 cima 
plt.plot([800,700],[400,375], c= 'k') #5 entorno janela 2 baixo
plt.plot([710,800],[255,262], c= 'k') #5 janela 2 cima 
plt.plot([710,800],[368,390], c= 'k') #5 janela 2 baixo

#vertical
plt.plot([300,250],[125,170], c= 'k') #1 telhado
plt.plot([300,300],[165,350], c= 'k') #2 parede
plt.plot([320,320],[220,360], c= 'k') #3 porta lado esquerda
plt.plot([380,380],[390,225], c= 'k') #3 porta lado direita
plt.plot([455,455],[307,235], c= 'k') #4 janela lado esquerdo
plt.plot([450,450],[310,228], c= 'k') #4 entorno janela lado esquerdo ----
plt.plot([590,590],[337,245], c= 'k') #4 janela lado direito
plt.plot([600,600],[350,237], c= 'k') #4 entorno janela lado direito
plt.plot([700,700],[245,375], c= 'k') #5 janela 2
plt.plot([710,710],[255,368], c= 'k') #5 entorno janela 2 baixo
plt.plot([300,800],[350,600], c= 'k') #6 chao

#---------- maçaneta  ------------
plt.scatter(365, 310,c= 'k', linewidth=5) #ponto de fuga 

#---------- efeito vidro ------------
plt.plot([510,550],[260,264], c= 'k') #janela 1 cima
plt.plot([520,545],[268,271], c= 'k') #janela 1 baixo

# visualização
plt.axis("off") 
plt.grid()
plt.imshow(img)
#plt.savefig('casa.png', format='png')
plt.show()
